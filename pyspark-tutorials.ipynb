# %%
df_order = spark.read.table('staging.default.orders_data')

# %%
df_order.display()

# %%
url = "https://raw.githubusercontent.com/Chichi126/databrick-pyspark-practice/5657acf8cac0d61c2df2860bc42d4dd170ab0598/Shipment_Data.csv"

# %%
import pandas as pd

# %%
df_shipment = pd.read_csv(url)

# %%
shipment = spark.createDataFrame(df_shipment)

# %%
shipment.write.format('delta').saveAsTable('staging.default.shipment_data')
